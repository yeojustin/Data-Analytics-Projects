# %% [markdown]
# 1. import the required libraries.
# 2. Read the dataset and print the first 50 rows.
# 3. How many attributes and instances are in the dataset?
# 4. Print the value counts of two attributes.
# 5. List some of the data characteristics.
# 6. How many missing values are in the dataset?
# 7. Which attributes have missing values?
# 8. What function to use to display the null values?
# 9. Using the replace function, replace NaN in the contact attribute with unknown.
# 10. Display the count of each marital status

# %%
# TODO 1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML 202/Topic4/bank.csv')

# %%
#TODO 2
pd.set_option('display.max_columns', None)
df.head(50)
# Out:
#     age            job   marital  education default  balance housing loan  \
# 0    30     unemployed   married    primary      no     1787      no   no
# 1    33       services   married  secondary      no     4789     yes  yes
# 2    35     management    single   tertiary      no     1350     yes   no
# 3    30     management   married   tertiary      no     1476     yes  yes
# 4    59    blue-collar   married  secondary      no        0     yes   no
# 5    35     management    single   tertiary      no      747      no   no
# 6    36  self-employed   married   tertiary      no      307     yes   no
# 7    39     technician   married  secondary      no      147     yes   no
# 8    41   entrepreneur   married   tertiary      no      221     yes   no
# 9    43       services   married    primary      no      -88     yes  yes
# 10   39       services   married  secondary      no     9374     yes   no
# 11   43         admin.   married  secondary      no      264     yes   no
# ...

# %%
#TODO 3
df.info()

# attribues - columns
# instances - rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4483 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4334 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    3197 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   816 non-null    object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
#TODO 4
df[['balance','duration']].describe()
# Out:
#             balance     duration
# count   4521.000000  4521.000000
# mean    1422.657819   263.961292
# std     3009.638142   259.856633
# min    -3313.000000     4.000000
# 25%       69.000000   104.000000
# 50%      444.000000   185.000000
# 75%     1480.000000   329.000000
# max    71188.000000  3025.000000

# %%
#TODO 5
df[['balance','duration']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   balance   4521 non-null   int64
#  1   duration  4521 non-null   int64
# dtypes: int64(2)
# memory usage: 70.8 KB

# %%
# TODO 6
df.isnull().sum()
# Out:
# age             0
# job            38
# marital         0
# education     187
# default         0
# balance         0
# housing         0
# loan            0
# contact      1324
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome     3705
# y               0
# dtype: int64

# %%
# TODO 7
df.fillna('unknown')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...
